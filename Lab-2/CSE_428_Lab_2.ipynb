# %%
import numpy as np
from skimage import io, color, exposure
import matplotlib.pyplot as plt

np.random.seed(1000)

# %%
I = np.random.rand(3, 3)
print(I)
# Out:
# [[0.65358959 0.11500694 0.95028286]
#  [0.4821914  0.87247454 0.21233268]
#  [0.04070962 0.39719446 0.2331322 ]]

# %%
io.imshow(I)
plt.axis("off")
# Out:
# C:\Users\Takee\AppData\Local\Temp\ipykernel_18308\1371413534.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(I)
# (np.float64(-0.5), np.float64(2.5), np.float64(2.5), np.float64(-0.5))

# %%
I2 = I + 0.5
print(I2)
# Out:
# [[1.15358959 0.61500694 1.45028286]
#  [0.9821914  1.37247454 0.71233268]
#  [0.54070962 0.89719446 0.7331322 ]]

# %%
# option 1
I2[I2 > 1] = 1
I2[I2 < 0] = 0

# option 2
I2 = np.clip(I+0.5, 0, 1)
plt.subplot(1, 2, 1)
io.imshow(I)
plt.axis("off")
# Out:
# C:\Users\Takee\AppData\Local\Temp\ipykernel_18308\386788808.py:8: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(I)
# (np.float64(-0.5), np.float64(2.5), np.float64(2.5), np.float64(-0.5))

# %%
plt.subplot(1, 2, 1)
io.imshow(I)
plt.axis("off")

plt.subplot(1, 2, 2)
io.imshow(I2)
plt.axis("off")
# Out:
# C:\Users\Takee\AppData\Local\Temp\ipykernel_18308\2163686046.py:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(I)
# C:\Users\Takee\AppData\Local\Temp\ipykernel_18308\2163686046.py:6: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(I2)
# (np.float64(-0.5), np.float64(2.5), np.float64(2.5), np.float64(-0.5))

# %%
I3 = np.clip(I - 0.5, 0, 1)

# %%
plt.subplot(1, 3, 1)
io.imshow(I)
plt.axis("off")
plt.title("original")

plt.subplot(1, 3, 2)
io.imshow(I2)
plt.axis("off")
plt.title("I+0.5")

plt.subplot(1, 3, 3)
io.imshow(I3)
plt.axis("off")
plt.title("I-0.5")
# Out:
# C:\Users\Takee\AppData\Local\Temp\ipykernel_18308\2929320904.py:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(I)
# C:\Users\Takee\AppData\Local\Temp\ipykernel_18308\2929320904.py:7: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(I2)
# C:\Users\Takee\AppData\Local\Temp\ipykernel_18308\2929320904.py:12: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(I3)
# Text(0.5, 1.0, 'I-0.5')

# %%
I2 = np.clip(I*2, 0, 1)
I3 = np.clip(I/2, 0, 1)

plt.subplot(1, 3, 1)
io.imshow(I)
plt.axis("off")
plt.title("original")

plt.subplot(1, 3, 2)
io.imshow(I2)
plt.axis("off")
plt.title("I*2")

plt.subplot(1, 3, 3)
io.imshow(I3)
plt.axis("off")
plt.title("I/2")
# Out:
# C:\Users\Takee\AppData\Local\Temp\ipykernel_18308\1930143978.py:5: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(I)
# C:\Users\Takee\AppData\Local\Temp\ipykernel_18308\1930143978.py:10: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(I2)
# C:\Users\Takee\AppData\Local\Temp\ipykernel_18308\1930143978.py:15: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(I3)
# Text(0.5, 1.0, 'I/2')

# %%
I = io.imread("landsat_down.png")
I = I/255.0
I.shape
# Out:
# (259, 273, 4)

# %%
print(I.min())
print(I.max())
# Out:
# 0.0
# 1.0

# %%
io.imshow(I)
plt.axis("off")
plt.show()
# Out:
# C:\Users\Takee\AppData\Local\Temp\ipykernel_18308\748734656.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(I)

# %%
#WRONG
I_stretched = 4*(I-0.1)

# %%
print(I_stretched.min())
print(I_stretched.max())
# Out:
# -0.4
# 3.6

# %%
#RIGHT
I_stretched = np.clip(4*(I-0.1), 0, 1)

# %%
io.imshow(I_stretched)
plt.axis("off")
plt.show()
# Out:
# C:\Users\Takee\AppData\Local\Temp\ipykernel_18308\3140916870.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(I_stretched)

# %%
hist, bins_hist = exposure.histogram(I, nbins=256, normalize=False)
plt.plot(bins_hist, hist, 'k')
plt.xlabel("Pixel values")
plt.ylabel("Count")
plt.title("Histogram before")

plt.twinx()
img_cdf, bins = exposure.cumulative_distribution(I, 256)
plt.plot(bins, img_cdf, "red")
plt.ylabel("Percentage")
plt.show()

# %%
hist, bins_hist = exposure.histogram(I_stretched, nbins=256, normalize=False)
plt.plot(bins_hist, hist, 'k')
plt.xlabel("Pixel values")
plt.ylabel("Count")
plt.title("Histogram after")

plt.twinx()
img_cdf, bins = exposure.cumulative_distribution(I_stretched, 256)
plt.plot(bins, img_cdf, "red")
plt.ylabel("Percentage")
plt.show()

# %%
I = io.imread("xray.jpg")/255
I = color.rgb2gray(I)

# %%
io.imshow(I)
plt.axis("off")
# Out:
# C:\Users\Takee\AppData\Local\Temp\ipykernel_18308\1371413534.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(I)
# (np.float64(-0.5), np.float64(320.5), np.float64(258.5), np.float64(-0.5))

# %%
k = 20
I2 = np.log(1 + k*I)
I2 = I2/I2.max()
io.imshow(I2)
# Out:
# C:\Users\Takee\AppData\Local\Temp\ipykernel_18308\415447733.py:4: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(I2)

# %%
I3 = 1 - I

# %%
io.imshow(I3)
# Out:
# C:\Users\Takee\AppData\Local\Temp\ipykernel_18308\15116087.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(I3)

# %%
gamma = 3
c = 1
I4 = c*(I ** gamma)
print(I4.min())
print(I4.max())
# Out:
# 0.0
# 1.0

# %%
io.imshow(I4)
# Out:
# C:\Users\Takee\AppData\Local\Temp\ipykernel_18308\791081932.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(I4)

# %%
I = io.imread("angiogram.jpg")
I = I[:,:,0]/255
I.shape
# Out:
# (910, 908)

# %%
io.imshow(1-I)
#plt.axis("off")
# Out:
# C:\Users\Takee\AppData\Local\Temp\ipykernel_18308\2681908769.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(1-I)

# %%
negImg = 1 - I

# %%
A = 0.6
B = 0.85
negImg[negImg < A] = 0
negImg[negImg > B] = 0

negImg[(negImg >= A) & (negImg <= B)] = 1

# %%
io.imshow(negImg)
# Out:
# C:\Users\Takee\AppData\Local\Temp\ipykernel_18308\1708544762.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(negImg)

# %%
negImg2 = 1 - I

# %%
A = 0.6
B = 0.85

negImg2[(negImg2 >= A) & (negImg2 <= B)] = 1

# %%
io.imshow(negImg2)
# Out:
# C:\Users\Takee\AppData\Local\Temp\ipykernel_18308\844899641.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(negImg2)

# %%
r ** gamma
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[176], line 1
# ----> 1 r ** gamma
#
# NameError: name 'r' is not defined
